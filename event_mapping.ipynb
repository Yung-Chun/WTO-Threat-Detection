# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import json
from datetime import datetime
import time
import matplotlib.pyplot as plt
import tiktoken
import requests
import ast
import zipfile
import io
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %% [markdown]
# ## Threat Detection Output

# %%
with open('threat_detection_output.json') as f:
        threat_detection_output = json.load(f)
        print(f'Loaded {len(threat_detection_output)} records')
# Out:
# Loaded 7598 records

# %%
threat_urls = list(threat_detection_output.keys())

# %%
threat_cnt = 0

for url in threat_detection_output.keys():
    if 'yes' in threat_detection_output[url].values():
        threat_cnt += 1

print(f'There are {threat_cnt} articles with threats')
print(f'The proportion of articles with threats is {threat_cnt/len(threat_detection_output)}')
# Out:
# There are 891 articles with threats
# The proportion of articles with threats is 0.11726770202684918

# %% [markdown]
# ## Event Extraction Output

# %% [markdown]
# ### Document info

# %%
document_info_merge = pd.read_csv('../WTO-Event-Extraction/results/full_wto_bertopic_document_info_merge_20240329_213505.csv')
print(f'length of merged_doc_info: {len(document_info_merge)}')
document_info_merge.head(3)
# Out:
# length of merged_doc_info: 8296
#    Topic                                               Name  \
# 0     19                     19_vaccine_dose_disaster_covax
# 1     11  11_adjudication_litigation_satisfactory_consul...
# 2     -1                       -1_pandemic_gatt_shall_panel
#
#                                       Representation  \
# 0  ['vaccine', 'dose', 'disaster', 'covax', 'supp...
# 1  ['adjudication', 'litigation', 'satisfactory',...
# 2  ['pandemic', 'gatt', 'shall', 'panel', 'reques...
#
#                                  Representative_Docs  \
# 0  ['deputy director general angela ellard discus...
# 1  ['european union request wto dispute consultat...
# 2  ["virtual address washington international tra...
#
#                                          Top_n_words  Probability  \
# 0  vaccine - dose - disaster - covax - supply - c...     0.059756
# 1  adjudication - litigation - satisfactory - con...     0.447425
# 2  pandemic - gatt - shall - panel - request - ge...     0.231426
#
#    Representative_document                                                url  \
# 0                    False  https://www.wto.org/english/news_e/news21_e/ig...
# 1                    False  https://www.wto.org/english/news_e/news18_e/ds...
# 2                    False  https://www.wto.org/english/news_e/spra_e/spra...
#
#          date
# 0  2021-11-29
# 1  2018-08-27
# 2  2018-03-19

# %%
document_info_merge.columns
# Out:
# Index(['Topic', 'Name', 'Representation', 'Representative_Docs', 'Top_n_words',
#        'Probability', 'Representative_document', 'url', 'date'],
#       dtype='object')

# %%
threat_events = []
columns = ['Topic', 'Name', 'url', 'date', 'isThreat', 'ThreatCount', 
           'isDisappointment', 'isDisappointment_reason', 'isComplain', 'isComplain_reason', 
           'isCritic', 'isCritic_reason', 'isAffect', 'isAffect_reason']

for row in document_info_merge.itertuples():
    res = [row.Topic, row.Name, row.url, row.date]

    if row.url in threat_urls:
        threat_res = list(threat_detection_output[row.url].values())
        
        # add boolean result
        if 'yes' in threat_res:
            res += [True]
        else:
            res += [False]
        
        # make it a scale
        res += [threat_res.count('yes')]
        # add meta info
        res += threat_res
    
    # for not-done urls or urls in gpt_errors.log
    else:
        res += [None] * 10

    threat_events.append(res)

threat_events = pd.DataFrame(threat_events, columns=columns)
print(f'length of threat_events: {len(threat_events)}')
threat_events.head(3)
# Out:
# length of threat_events: 8296
#    Topic                                               Name  \
# 0     19                     19_vaccine_dose_disaster_covax
# 1     11  11_adjudication_litigation_satisfactory_consul...
# 2     -1                       -1_pandemic_gatt_shall_panel
#
#                                                  url        date isThreat  \
# 0  https://www.wto.org/english/news_e/news21_e/ig...  2021-11-29    False
# 1  https://www.wto.org/english/news_e/news18_e/ds...  2018-08-27     True
# 2  https://www.wto.org/english/news_e/spra_e/spra...  2018-03-19     True
#
#    ThreatCount isDisappointment  \
# 0          0.0               no
# 1          2.0               no
# 2          3.0               no
#
#                              isDisappointment_reason isComplain  \
# 0  The article does not express any disappointmen...         no
# 1  The article does not express any emotions such...        yes
# 2  The article does not explicitly express any di...        yes
#
#                                    isComplain_reason isCritic  \
# 0  There are no complaints about the United State...       no
# 1  China's request for consultations under the WT...       no
# 2  The article mentions concerns over protectioni...      yes
#
#                                      isCritic_reason isAffect  \
# 0  The article does not contain any criticism of ...       no
# 1  The article does not contain any direct critic...      yes
# 2  The article criticizes the rise of protectioni...      yes
#
#                                      isAffect_reason
# 0  The article does not imply a need for policy c...
# 1  The initiation of a dispute suggests that ther...
# 2  The call for resolving trade tensions and stre...

# %%
threat_events.to_csv('threat_events_document_info_merge.csv', index=False)

# %% [markdown]
# ### Topic info

# %%
topic_info_merge = pd.read_csv('../WTO-Event-Extraction/results/full_wto_bertopic_topic_info_merge_20240329_213505.csv')
print(f'length of merged_topic_info: {len(topic_info_merge)}')
topic_info_merge.head(3)
# Out:
# length of merged_topic_info: 156
#    Topic  Count                                 Name  \
# 0     -1   1859         -1_pandemic_gatt_shall_panel
# 1      0    537  0_climate_environmental_food_energy
# 2      1    283     1_university_rtpc_essay_academic
#
#                                       Representation  \
# 0  ['pandemic', 'gatt', 'shall', 'panel', 'reques...
# 1  ['climate', 'environmental', 'food', 'energy',...
# 2  ['university', 'rtpc', 'essay', 'academic', 'c...
#
#                                  Representative_Docs  \
# 0  ["virtual address washington international tra...
# 1  ['day wto public forum october panel workshop ...
# 2  ['wto issue young economist submit paper wto e...
#
#                                  Representation_n1-2
# 0  ['panel', 'request', 'general', 'multilateral'...
# 1  ['climate', 'environmental', 'food', 'climate ...
# 2  ['university', 'rtpc', 'academic', 'essay', 'c...

# %%
total_article = np.sum(topic_info_merge['Count'])

# %%
threat_events.head(3)
# Out:
#    Topic                                               Name  \
# 0     19                     19_vaccine_dose_disaster_covax
# 1     11  11_adjudication_litigation_satisfactory_consul...
# 2     -1                       -1_pandemic_gatt_shall_panel
#
#                                                  url        date isThreat  \
# 0  https://www.wto.org/english/news_e/news21_e/ig...  2021-11-29    False
# 1  https://www.wto.org/english/news_e/news18_e/ds...  2018-08-27     True
# 2  https://www.wto.org/english/news_e/spra_e/spra...  2018-03-19     True
#
#    ThreatCount isDisappointment  \
# 0          0.0               no
# 1          2.0               no
# 2          3.0               no
#
#                              isDisappointment_reason isComplain  \
# 0  The article does not express any disappointmen...         no
# 1  The article does not express any emotions such...        yes
# 2  The article does not explicitly express any di...        yes
#
#                                    isComplain_reason isCritic  \
# 0  There are no complaints about the United State...       no
# 1  China's request for consultations under the WT...       no
# 2  The article mentions concerns over protectioni...      yes
#
#                                      isCritic_reason isAffect  \
# 0  The article does not contain any criticism of ...       no
# 1  The article does not contain any direct critic...      yes
# 2  The article criticizes the rise of protectioni...      yes
#
#                                      isAffect_reason
# 0  The article does not imply a need for policy c...
# 1  The initiation of a dispute suggests that ther...
# 2  The call for resolving trade tensions and stre...

# %%
# calculate ThreatRate
threat_events_topic = threat_events[['Topic', 'isThreat', 'ThreatCount']].groupby('Topic').agg({'isThreat': 'sum'}).reset_index()
threat_events_topic.fillna(0, inplace=True)

for row in threat_events_topic.itertuples():
#     # per topic
#     if row.ThreatCount != 0:
#         threat_events_topic.at[row.Index, 'LocalThreatRate'] = row.isThreat / row.Count
#     else:
#         threat_events_topic.at[row.Index, 'LocalThreatRate'] = 0

    # global
    threat_events_topic.at[row.Index, 'GlobalThreatRate'] = row.isThreat / total_article

threat_events_topic.head(3)
# Out:
#    Topic isThreat  GlobalThreatRate
# 0     -1      219          0.026398
# 1      0       90          0.010849
# 2      1        0          0.000000

# %%
threat_events_topic_info_merge = pd.merge(threat_events_topic, topic_info_merge, on='Topic', how='left')
threat_events_topic_info_merge['LocalThreatRate'] = threat_events_topic_info_merge['isThreat'] / threat_events_topic_info_merge['Count']
threat_events_topic_info_merge = threat_events_topic_info_merge.reindex(columns=['Topic', 'Name', 'isThreat', 'Count',
                                                                                 'LocalThreatRate', 'GlobalThreatRate', 
                                                                                 'Name', 'Representation', 'Representative_Docs', 'Representation_n1-2'])
print(f'length of threat_events_topic_info_merge: {len(threat_events_topic_info_merge)}')
threat_events_topic_info_merge.head(3)
# Out:
# length of threat_events_topic_info_merge: 156
#    Topic                                 Name isThreat  Count LocalThreatRate  \
# 0     -1         -1_pandemic_gatt_shall_panel      219   1859        0.117805
# 1      0  0_climate_environmental_food_energy       90    537        0.167598
# 2      1     1_university_rtpc_essay_academic        0    283             0.0
#
#    GlobalThreatRate                                 Name  \
# 0          0.026398         -1_pandemic_gatt_shall_panel
# 1          0.010849  0_climate_environmental_food_energy
# 2          0.000000     1_university_rtpc_essay_academic
#
#                                       Representation  \
# 0  ['pandemic', 'gatt', 'shall', 'panel', 'reques...
# 1  ['climate', 'environmental', 'food', 'energy',...
# 2  ['university', 'rtpc', 'essay', 'academic', 'c...
#
#                                  Representative_Docs  \
# 0  ["virtual address washington international tra...
# 1  ['day wto public forum october panel workshop ...
# 2  ['wto issue young economist submit paper wto e...
#
#                                  Representation_n1-2
# 0  ['panel', 'request', 'general', 'multilateral'...
# 1  ['climate', 'environmental', 'food', 'climate ...
# 2  ['university', 'rtpc', 'academic', 'essay', 'c...

# %%
threat_events_topic_info_merge.to_csv('threat_events_topic_info_merge.csv', index=False)
